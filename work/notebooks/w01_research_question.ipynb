# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saiteja-025/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### Lane: Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because websites often have many pages, and it is difficult to know which pages should be refreshed first. Using search performance data, I want to identify pages that are most likely to benefit from content updates. This can help the SEO or content team spend their time on high-priority pages instead of reviewing every page manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Which web pages should be refreshed first to improve search performance?
#
# **Unit of Analysis:** One web page.
#
# **Output:** A ranked list of web pages that should be refreshed based on their opportunity score.
#
# **Action:** The SEO or content team updates the recommended pages before reviewing lower-priority pages.
#
# **Cost of a Wrong Recommendation:** If a high-potential page is not selected, it may continue losing search traffic. If a low-priority page is selected instead, time and effort are wasted.
#
# **Why ML Helps:** Machine Learning can analyze multiple search performance metrics together and identify pages that are more likely to benefit from a content refresh than manual analysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# I loaded the starter dataset and explored a few basic statistics to understand whether this problem is worth studying. The numbers below provide an initial overview of the dataset and support my decision to work on the Refresh / Content Opportunity Scoring lane.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("./flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

# Display 3 real numbers
print("Total Pages:", len(df))

if "ctr" in df.columns:
    print("Average CTR:", round(df["ctr"].mean(), 4))

if "avg_position" in df.columns:
    print("Average Position:", round(df["avg_position"].mean(), 2))

# Show the available columns
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Total Pages: 30000
# Average CTR: 0.5107
# Average Position: 16.34
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project is based on observations from the provided anonymized dataset. The results are intended to support decision-making by identifying pages that may benefit from content updates.
#
# This project cannot prove how Google's search ranking algorithm works or guarantee future ranking improvements. It only identifies patterns in the available data and provides decision support based on those observations.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
